# %%
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pylab as pl
import seaborn as sb

# %%
datos = pd.read_excel("Clientes.xlsx")

# %%
datos.head()
# Out:
#    cedula   oficina categori  tiempode       monto       saldo  plazo    tasa  \
# 0    6754  SANTA FE        E        63    500000.0    411775.0     18  3.1667
# 1   17922     LA 80        E        65   2000000.0   1563604.0     24  3.2083
# 2     167   USAQUEN        E        60    800000.0    658843.0     18  3.1667
# 3   23093  SANTA FE        E        57    800000.0    744568.0     21  3.2083
# 4   16530   USAQUEN        E        58  14153655.0  13567368.0     48  2.8750
#
#     cuota garantia ...      estadoci       sexo  personas  tipovivi  \
# 0   36868        P ...   Unión Libre  Masculino         0       NaN
# 1  120761        P ...       Soltero  Masculino         0       NaN
# 2   58990        P ...       Soltero   Femenino         0       NaN
# 3   52945        P ...        Casado  Masculino         0  Familiar
# 4  547318        R ...        Casado  Masculino         2    Propia
#
#              tipocont   aportes  numerocr  antigcoo  default  Cat
# 0                 NaN   69000.0         1         6     Malo    E
# 1                 NaN       0.0         1         6     Malo    E
# 2                 NaN   82000.0         1         5     Malo    E
# 3  Término Indefinido   82000.0         1         5     Malo    E
# 4                 NaN  300000.0         1         7     Malo    E
#
# [5 rows x 30 columns]

# %%
datos.shape
# Out:
# (24786, 30)

# %% [markdown]
# # Datos Perdidos

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24786 entries, 0 to 24785
# Data columns (total 30 columns):
# cedula      24786 non-null int64
# oficina     24786 non-null object
# categori    24786 non-null object
# tiempode    24786 non-null int64
# monto       24786 non-null float64
# saldo       24786 non-null float64
# plazo       24786 non-null int64
# tasa        24786 non-null float64
# cuota       24786 non-null int64
# garantia    24786 non-null object
# diasmora    24786 non-null int64
# formapag    24786 non-null int64
# reestruc    24786 non-null int64
# edad        24786 non-null int64
# ocupació    24786 non-null object
# niveledu    24786 non-null object
# ingtot      24786 non-null float64
# egrtot      24786 non-null float64
# estrato     24786 non-null int64
# antigemp    24786 non-null int64
# estadoci    24786 non-null object
# sexo        24786 non-null object
# personas    24786 non-null int64
# tipovivi    20414 non-null object
# tipocont    19595 non-null object
# aportes     24786 non-null float64
# numerocr    24786 non-null int64
# antigcoo    24786 non-null int64
# default     24786 non-null object
# Cat         24786 non-null object
# dtypes: float64(6), int64(13), object(11)
# memory usage: 5.7+ MB

# %%
nulos = datos.count()/len(datos.index)
nulos ###Contando la proporción de datos no nulos
# Out:
# cedula      1.000000
# oficina     1.000000
# categori    1.000000
# tiempode    1.000000
# monto       1.000000
# saldo       1.000000
# plazo       1.000000
# tasa        1.000000
# cuota       1.000000
# garantia    1.000000
# diasmora    1.000000
# formapag    1.000000
# reestruc    1.000000
# edad        1.000000
# ocupació    1.000000
# niveledu    1.000000
# ingtot      1.000000
# egrtot      1.000000
# estrato     1.000000
# antigemp    1.000000
# estadoci    1.000000
# sexo        1.000000
# personas    1.000000
# tipovivi    0.823610
# tipocont    0.790567
# aportes     1.000000
# numerocr    1.000000
# antigcoo    1.000000
# default     1.000000
# Cat         1.000000
# dtype: float64

# %%
len(datos.dropna(subset=['tipocont']))
# Out:
# 19595

# %%
# Mapa de calor para identificar donde faltan datos 
sns.heatmap(datos.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.show()

# %% [markdown]
# Las lineas amarillas me indican los datos perdidos o nulos

# %%
NA_tipovivi = 1-len(datos.dropna(subset=['tipovivi']))/len(datos)
NA_tipovivi ##Proporción de los datos faltantes
# Out:
# 0.1763898975227951

# %%
NA_tipocont = 1-len(datos.dropna(subset=['tipocont']))/len(datos)
NA_tipocont
# Out:
# 0.20943274429113212

# %%
datos.columns
# Out:
# Index(['cedula', 'oficina', 'categori', 'tiempode', 'monto', 'saldo', 'plazo',
#        'tasa', 'cuota', 'garantia', 'diasmora', 'formapag', 'reestruc', 'edad',
#        'ocupació', 'niveledu', 'ingtot', 'egrtot', 'estrato', 'antigemp',
#        'estadoci', 'sexo', 'personas', 'tipovivi', 'tipocont', 'aportes',
#        'numerocr', 'antigcoo', 'default', 'Cat'],
#       dtype='object')

# %% [markdown]
# Solamente el 17.6% de los datos de tipovivi y el 20.9% de los datos tipocont no son nulos, por tanto puedo considerar en quitar estas variables

# %% [markdown]
# ## Análisis descriptivo

# %%
sns.pairplot(data=datos, hue='default', plot_kws=None)

# %%
sns.set_style('whitegrid')
sns.countplot(x='default',data=datos, palette='RdBu_r')
plt.show()

# %%
sns.countplot(x='default',hue='tipovivi',data=datos, palette='RdBu_r')
plt.show()

# %%
sns.countplot(x='default',hue='sexo',data=datos, palette='RdBu_r')

# %%
datos['edad'].hist(bins=30,color='darkred',alpha=0.7)

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='sexo', y='edad',data=datos,palette='winter')
plt.show()

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='sexo', y='monto',data=datos,palette='winter')
plt.show()

# %%
corr = datos.corr()

plt.figure(figsize = (12,10))

sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            cmap = 'Blues');

# %%
corr
# Out:
#             cedula  tiempode     monto     saldo     plazo      tasa  \
# cedula    1.000000  0.003063  0.003787  0.005264  0.009407 -0.003959
# tiempode  0.003063  1.000000  0.235246 -0.032490  0.285349  0.117785
# monto     0.003787  0.235246  1.000000  0.937122  0.718654 -0.139144
# saldo     0.005264 -0.032490  0.937122  1.000000  0.714914 -0.120100
# plazo     0.009407  0.285349  0.718654  0.714914  1.000000 -0.118068
# tasa     -0.003959  0.117785 -0.139144 -0.120100 -0.118068  1.000000
# cuota     0.001245  0.219135  0.954681  0.867832  0.572668 -0.109260
# diasmora  0.008981  0.339700 -0.021972 -0.033243 -0.028595  0.503644
# formapag  0.001096 -0.045693  0.070255  0.077950  0.080499 -0.155274
# reestruc  0.005575 -0.002427 -0.022289 -0.023235 -0.026031  0.002212
# edad      0.026681  0.082263  0.161749  0.140092  0.156635 -0.019008
# ingtot   -0.002463  0.103648  0.441485  0.395482  0.290819 -0.065563
# egrtot    0.003659  0.009168  0.312036  0.294723  0.203015 -0.067454
# estrato   0.007395  0.095241  0.228859  0.196658  0.171776 -0.033666
# antigemp  0.007548  0.067715  0.116661  0.097611  0.112299 -0.026826
# personas -0.005115 -0.126784 -0.002677  0.027621  0.003982 -0.035592
# aportes   0.007529  0.109101  0.282140  0.245485  0.259578 -0.096883
# numerocr  0.011653 -0.100587  0.081018  0.115109  0.111259 -0.060283
# antigcoo  0.016013  0.236620  0.163209  0.104538  0.178433 -0.004701
#
#              cuota  diasmora  formapag  reestruc      edad    ingtot  \
# cedula    0.001245  0.008981  0.001096  0.005575  0.026681 -0.002463
# tiempode  0.219135  0.339700 -0.045693 -0.002427  0.082263  0.103648
# monto     0.954681 -0.021972  0.070255 -0.022289  0.161749  0.441485
# saldo     0.867832 -0.033243  0.077950 -0.023235  0.140092  0.395482
# plazo     0.572668 -0.028595  0.080499 -0.026031  0.156635  0.290819
# tasa     -0.109260  0.503644 -0.155274  0.002212 -0.019008 -0.065563
# cuota     1.000000 -0.014810  0.055754 -0.018444  0.161994  0.482376
# diasmora -0.014810  1.000000 -0.025244  0.001298 -0.034339 -0.047809
# formapag  0.055754 -0.025244  1.000000  0.009513 -0.021392  0.010247
# reestruc -0.018444  0.001298  0.009513  1.000000 -0.005467 -0.002304
# edad      0.161994 -0.034339 -0.021392 -0.005467  1.000000  0.218360
# ingtot    0.482376 -0.047809  0.010247 -0.002304  0.218360  1.000000
# egrtot    0.332692 -0.091464  0.012418 -0.003297  0.158330  0.673465
# estrato   0.249752 -0.005578  0.019266 -0.015259  0.103554  0.322805
# antigemp  0.118120 -0.015712  0.066630  0.011488  0.162845  0.105473
# personas -0.011728 -0.078090  0.038414 -0.005364  0.099346  0.072526
# aportes   0.279831 -0.039084 -0.028612 -0.027873  0.256784  0.191499
# numerocr  0.078594 -0.061878  0.018753 -0.026732  0.220240  0.043372
# antigcoo  0.164650  0.036642 -0.067768 -0.023267  0.304917  0.123274
#
#             egrtot   estrato  antigemp  personas   aportes  numerocr  antigcoo
# cedula    0.003659  0.007395  0.007548 -0.005115  0.007529  0.011653  0.016013
# tiempode  0.009168  0.095241  0.067715 -0.126784  0.109101 -0.100587  0.236620
# monto     0.312036  0.228859  0.116661 -0.002677  0.282140  0.081018  0.163209
# saldo     0.294723  0.196658  0.097611  0.027621  0.245485  0.115109  0.104538
# plazo     0.203015  0.171776  0.112299  0.003982  0.259578  0.111259  0.178433
# tasa     -0.067454 -0.033666 -0.026826 -0.035592 -0.096883 -0.060283 -0.004701
# cuota     0.332692  0.249752  0.118120 -0.011728  0.279831  0.078594  0.164650
# diasmora -0.091464 -0.005578 -0.015712 -0.078090 -0.039084 -0.061878  0.036642
# formapag  0.012418  0.019266  0.066630  0.038414 -0.028612  0.018753 -0.067768
# reestruc -0.003297 -0.015259  0.011488 -0.005364 -0.027873 -0.026732 -0.023267
# edad      0.158330  0.103554  0.162845  0.099346  0.256784  0.220240  0.304917
# ingtot    0.673465  0.322805  0.105473  0.072526  0.191499  0.043372  0.123274
# egrtot    1.000000  0.210105  0.063263  0.208653  0.185429  0.059185  0.090224
# estrato   0.210105  1.000000  0.052211 -0.170343  0.064230 -0.039206  0.034648
# antigemp  0.063263  0.052211  1.000000  0.107381  0.043667  0.073120  0.073871
# personas  0.208653 -0.170343  0.107381  1.000000  0.047762  0.062539  0.001299
# aportes   0.185429  0.064230  0.043667  0.047762  1.000000  0.528445  0.549599
# numerocr  0.059185 -0.039206  0.073120  0.062539  0.528445  1.000000  0.617715
# antigcoo  0.090224  0.034648  0.073871  0.001299  0.549599  0.617715  1.000000

# %%
datos.drop(['tipovivi', 'cedula', 'tipocont','cuota','plazo','monto','egrtot','numerocr','antigcoo'],axis=1,inplace=True)

# %% [markdown]
# De las variables que se encuentran correlacionadas se selecciona una variable

# %%
corr = datos.corr()

plt.figure(figsize = (12,10))

sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            cmap = 'Blues');

# %% [markdown]
# # Conversión de variable categorica

# %%
z = pd.Series(datos['sexo'])
z.value_counts()
# Out:
# Masculino    12500
# Femenino     12286
# Name: sexo, dtype: int64

# %%
datos.head()
# Out:
#     oficina categori  tiempode       saldo    tasa garantia  diasmora  \
# 0  SANTA FE        E        63    411775.0  3.1667        P      1784
# 1     LA 80        E        65   1563604.0  3.2083        P      1758
# 2   USAQUEN        E        60    658843.0  3.1667        P      1677
# 3  SANTA FE        E        57    744568.0  3.2083        P      1670
# 4   USAQUEN        E        58  13567368.0  2.8750        R      1621
#
#    formapag  reestruc  edad ...       niveledu     ingtot  estrato  antigemp  \
# 0         1         2    30 ...   Bachillerato   372315.0        3         6
# 1         1         2    38 ...   Bachillerato   900000.0        2         8
# 2         1         2    57 ...        Técnico   800000.0        4        14
# 3         1         2    28 ...   Bachillerato   325000.0        3         8
# 4         1         2    46 ...  Universitario  2500000.0        5         0
#
#       estadoci       sexo personas   aportes  default Cat
# 0  Unión Libre  Masculino        0   69000.0     Malo   E
# 1      Soltero  Masculino        0       0.0     Malo   E
# 2      Soltero   Femenino        0   82000.0     Malo   E
# 3       Casado  Masculino        0   82000.0     Malo   E
# 4       Casado  Masculino        2  300000.0     Malo   E
#
# [5 rows x 21 columns]

# %%
z = pd.Series(datos['estadoci'])
z.value_counts()
# Out:
# Casado          12135
# Soltero          7601
# Unión Libre      2150
# Separado         1701
# Viudo            1189
# Eclesiástico       10
# Name: estadoci, dtype: int64

# %%
category_col = datos.columns

for col in category_col:
    b, c = np.unique(datos[col], return_inverse = True)
    datos[col] = c

# %%
datos.head()
# Out:
#    oficina  categori  tiempode  saldo  tasa  garantia  diasmora  formapag  \
# 0        4         4        61   1340    57         0       401         0
# 1        3         4        63   5669    58         0       400         0
# 2        7         4        58   2394    57         0       399         0
# 3        4         4        55   2746    58         0       398         0
# 4        7         4        56  12477    53         1       397         0
#
#    reestruc  edad ...   niveledu  ingtot  estrato  antigemp  estadoci  sexo  \
# 0         1    11 ...          0     198        3         7         4     1
# 1         1    19 ...          0    3448        2         9         3     1
# 2         1    38 ...          5    2796        4        15         3     0
# 3         1     9 ...          0      59        3         9         0     1
# 4         1    27 ...          6    7343        5         1         0     1
#
#    personas  aportes  default  Cat
# 0         0      170        1    4
# 1         0        0        1    4
# 2         0      198        1    4
# 3         0      198        1    4
# 4         2      595        1    4
#
# [5 rows x 21 columns]

# %%
z = pd.Series(datos['default'])
z.value_counts()
# Out:
# 0    24334
# 1      452
# Name: default, dtype: int64

# %% [markdown]
# # Construcción del modelo
#
# La variable predictora es binomial por tanto el modelo que voy a utilizar es una  Regresion logistica

# %%
from sklearn.model_selection import train_test_split

# %%
X = datos.drop('default',axis=1)
y = datos['default']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, test_size=0.30, 
                                                    random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression()
classifier.fit(X_train,y_train)
predictions = classifier.predict(X_test)

# %% [markdown]
# # Evaluación del modelo

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      7289
#           1       0.97      0.96      0.97       147
#
# avg / total       1.00      1.00      1.00      7436

# %%
prediction = classifier.predict(X)
np.mean(prediction == y)
# Out:
# 0.9985475671750181

# %%
classifier.score(X, y)
# Out:
# 0.9985475671750181

# %% [markdown]
# Se observa los datos se ajustan muy bien al modelo, ya logra predecir con exactitud cuales son los clientes "Buenos" y con 95% los clientes "Malos"

# %%
from sklearn.metrics import confusion_matrix

prediction = classifier.predict(X)
cnf_matrix = confusion_matrix(y, prediction)

# %%
print(cnf_matrix)
# Out:
# [[24318    16]
#  [   20   432]]

# %%
z = pd.Series(datos['default'])
z.value_counts()
# Out:
# 0    24334
# 1      452
# Name: default, dtype: int64

# %% [markdown]
# La matriz de confusión muestra que de 24334 ejemplos de clientes "Buenos" supo clasificar 24317. Mientras que de 452 ejemplos de clientes "Malos", se equivocó en 17.
